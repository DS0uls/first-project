# %% [markdown]
# Привет! меня зовут Люман Аблаев. Сегодня я проверю твой проект.
# <br> Дальнейшее общение будет происходить на "ты" если это не вызывает никаких проблем.
# <br> Желательно реагировать на каждый мой комментарий ('исправил', 'не понятно как исправить ошибку', ...)
# <br> Пожалуйста, не удаляй комментарии ревьюера, так как они повышают качество повторного ревью.
#
# Комментарии будут в <font color='green'>зеленой</font>, <font color='blue'>синей</font> или <font color='red'>красной</font> рамках:чйв
#
#
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Если все сделано отлично
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет: </b> Если можно немного улучшить
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Если требуются исправления. Работа не может быть принята с красными комментариями.
# </div>
#
# <font color='orange' style='font-size:24px; font-weight:bold'>Полезные ссылки</font>
# * Очень интересная и полезная статья: https://dyakonov.org/2021/05/27/imbalance/
#
# <font color='orange' style='font-size:24px; font-weight:bold'>Общее впечатление</font>
# * Спасибо за  качественную работу, мне она очень понравилась
# - Радует, что анализу данных и их предобработке данных уделено должное внимание.
# - Я оставил некоторые советы, надеюсь они будут полезными или интересными.
# - В работе, есть некоторые недочеты, которые нужно поправить и обновить ноутбук
# - Жду обновленную работу

# %% [markdown]
# <font color='orange' style='font-size:24px; font-weight:bold'>Общее впечатление[ИТОГ]</font>
# * Спасибо за усредность, видно, что ты стараешься и это заслуживает похвалы
# - Приятно видеть фидбек на комментарии.
# - Недочеты исправлены - работа полностью корректна
# - Не стесняйся задавать вопросы, наставник, преподователь и ревьюверы с радостью тебе помогут разобраться в какой-то теме.
# - Рад был быть полезен. Удачи в дальнейшем обучении!

# %% [markdown]
# <div class="alert alert-info">
# <b></b>
# <br>help me
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ревьювер:</b> Постараюсь) Внизу много критики, сильно не пугайся, если что не понятно спрашивай.
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span></li><li><span><a href="#Исследуем-баланс-классов" data-toc-modified-id="Исследуем-баланс-классов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследуем баланс классов</a></span><ul class="toc-item"><li><span><a href="#Промежуточный-итог:" data-toc-modified-id="Промежуточный-итог:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Промежуточный итог:</a></span></li><li><span><a href="#Промежуточный-итог:" data-toc-modified-id="Промежуточный-итог:-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Промежуточный итог:</a></span></li><li><span><a href="#Промежуточный-итог:" data-toc-modified-id="Промежуточный-итог:-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Промежуточный итог:</a></span></li><li><span><a href="#Промежуточный-итог:" data-toc-modified-id="Промежуточный-итог:-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Промежуточный итог:</a></span></li><li><span><a href="#Строим-модель-без-учёта-баланса:" data-toc-modified-id="Строим-модель-без-учёта-баланса:-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Строим модель без учёта баланса:</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Промежуточный-итог:" data-toc-modified-id="Промежуточный-итог:-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Промежуточный итог:</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Промежуточный-итог:" data-toc-modified-id="Промежуточный-итог:-3.5.4"><span class="toc-item-num">3.5.4&nbsp;&nbsp;</span>Промежуточный итог:</a></span></li><li><span><a href="#Промежуточный-итог:" data-toc-modified-id="Промежуточный-итог:-3.5.5"><span class="toc-item-num">3.5.5&nbsp;&nbsp;</span>Промежуточный итог:</a></span></li></ul></li><li><span><a href="#Обучение-с-помощью-модели-Логистической-регрессии" data-toc-modified-id="Обучение-с-помощью-модели-Логистической-регрессии-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Обучение с помощью модели Логистической регрессии</a></span><ul class="toc-item"><li><span><a href="#Промежуточный-итог:" data-toc-modified-id="Промежуточный-итог:-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Промежуточный итог:</a></span></li><li><span><a href="#Общий-вывод:" data-toc-modified-id="Общий-вывод:-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Общий вывод:</a></span></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Upsampling" data-toc-modified-id="Upsampling-3.7.1"><span class="toc-item-num">3.7.1&nbsp;&nbsp;</span>Upsampling</a></span></li><li><span><a href="#Downsampling" data-toc-modified-id="Downsampling-3.7.2"><span class="toc-item-num">3.7.2&nbsp;&nbsp;</span>Downsampling</a></span></li></ul></li><li><span><a href="#После-балансирования-данных.-Обучение-с-помощью-модели-Дерево-решения" data-toc-modified-id="После-балансирования-данных.-Обучение-с-помощью-модели-Дерево-решения-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>После балансирования данных. Обучение с помощью модели Дерево решения</a></span></li><li><span><a href="#После-балансирования-данных.-Обучение-с-помощью-модели-Случайный-лес" data-toc-modified-id="После-балансирования-данных.-Обучение-с-помощью-модели-Случайный-лес-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>После балансирования данных. Обучение с помощью модели Случайный лес</a></span></li><li><span><a href="#После-балансирования-данных.-Обучение-с-помощью-модели-Логистической-регрессии" data-toc-modified-id="После-балансирования-данных.-Обучение-с-помощью-модели-Логистической-регрессии-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>После балансирования данных. Обучение с помощью модели Логистической регрессии</a></span></li><li><span><a href="#Итог:" data-toc-modified-id="Итог:-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Итог:</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><span><a href="#итог-тестирования:" data-toc-modified-id="итог-тестирования:-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>итог тестирования:</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# # Признаки:
# 1.	RowNumber — индекс строки в данных
# 2.	CustomerId — уникальный идентификатор клиента
# 3.	Surname — фамилия
# 4.	CreditScore — кредитный рейтинг
# 5.	Geography — страна проживания
# 6.	Gender — пол
# 7.	Age — возраст
# 8.	Tenure — сколько лет человек является клиентом банка
# 9.	Balance — баланс на счёте
# 10.	NumOfProducts — количество продуктов банка, используемых клиентом
# 11.	HasCrCard — наличие кредитной карты
# 12.	IsActiveMember — активность клиента
# 13.	EstimatedSalary — предполагаемая зарплата
#
# <p>Целевой признак:</p>
# 14. Exited — факт ухода клиента

# %% [markdown]
# ## Подготовка данных

# %%
#подключаем библиотеки: 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_absolute_error

from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import shuffle
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
import numpy as np


# Скроем предупреждения, чтобы не мозолили глаза
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Импорты на месте
# </div>

# %% [markdown]
# ## Исследование задачи

# %%
#чтение файла: 
df = pd.read_csv('/datasets/Churn.csv')
df.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
#общие данные
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age       Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  9091.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800     4.997690
# std     2886.89568  7.193619e+04     96.653299     10.487806     2.894723
# min        1.00000  1.556570e+07    350.000000     18.000000     0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000     2.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000     5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000     7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
#типы данных
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure             float64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
#проверяю что бы у уникальных ID не было задвоенных значений. 
# т.е. исключаю случай при котором, "клиент" - ушёл --> вернулся --> вновь ушёл. (при таком раскладе было бы значение == 2)
df.groupby('CustomerId')['Exited'].count()
# Out:
# CustomerId
# 15565701    1
# 15565706    1
# 15565714    1
# 15565779    1
# 15565796    1
#            ..
# 15815628    1
# 15815645    1
# 15815656    1
# 15815660    1
# 15815690    1
# Name: Exited, Length: 10000, dtype: int64

# %%
#количество ушедших клиентов
df.query('Exited == 1').count()
# Out:
# RowNumber          2037
# CustomerId         2037
# Surname            2037
# CreditScore        2037
# Geography          2037
# Gender             2037
# Age                2037
# Tenure             1854
# Balance            2037
# NumOfProducts      2037
# HasCrCard          2037
# IsActiveMember     2037
# EstimatedSalary    2037
# Exited             2037
# dtype: int64

# %%
#уточняю что в столбце Tenure (продолжительность обслуживания банком)
tr = df.groupby('Tenure')['Exited'].count()
print(tr)
print('Количество заполненых значений:', tr.sum())

print('Количество Nan:', len(df) - tr.sum())
# Out:
# Tenure
# 0.0     382
# 1.0     952
# 2.0     950
# 3.0     928
# 4.0     885
# 5.0     927
# 6.0     881
# 7.0     925
# 8.0     933
# 9.0     882
# 10.0    446
# Name: Exited, dtype: int64
# Количество заполненых значений: 9091
# Количество Nan: 909

# %%
#заполним пропуски нулями
df['Tenure']=df['Tenure'].fillna(0).astype('int64')
#проверяем исправление:
df.count()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname            10000
# CreditScore        10000
# Geography          10000
# Gender             10000
# Age                10000
# Tenure             10000
# Balance            10000
# NumOfProducts      10000
# HasCrCard          10000
# IsActiveMember     10000
# EstimatedSalary    10000
# Exited             10000
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Совет:</b> Пропуски проанализированы логично и решение заполнить их таким образом - допустимое . Но мне кажется, что так как природа пропусков неизвестна можно заполнить их случайными числами, чтобы не влиять на распределение

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> Всё таки считаю, что тут должен быть 0. т.к. или на основании того, что NAN меньше 10% - отсечь эти данные.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[2]:</b>  Ок, здесь нет единственного решения

# %%
#проверка значений в целевом признаке
df['Exited'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# # Итог:
# 1. импортировали библиотеки;
# 2. прочитали csv файл;
# 3. изучили файл;
# 4. всего клиентов в df = 10000 из которых ушли 2037.
# 5. В были пропуски в Tenure (продолжительность обслуживания банком) - их заполнили нулями.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет </b>  Советую обратить внимание на библиотеки sweetviz и pandas_profiling помогут в проведении более тщательного EDA анализа. Исследовательский анализ можно делать и с помощью ручного вызова функций дефолтных библиотек. Данные библиотеки хороши для максимизации комфорта презентации результатов анализа бизнес-пользователям.
#
# Очень просты в использоовании, на вход кладется датафрейм: pandas_profiling.ProfileReport(df)
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> Прочитал https://habr.com/ru/post/564172/ и https://towardsdatascience.com/accelerate-your-exploratory-data-analysis-with-pandas-profiling-4eca0cb770d1
#     <br>в текущей тетрадке не получилось (именно от Яндекс) https://disk.yandex.ru/i/gwbwx7hX8kp4Qw
#     <br>а вот на локальном - получилось. <a href='https://disk.yandex.ru/i/N4QxFI0QPp80kw'> https://disk.yandex.ru/i/N4QxFI0QPp80kw</a>
#     <br>спасибо буду пользоваться.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[2]:</b>  Здесь можно установить пакеты : `!pip install sweetviz`

# %%
#import sweetviz as sv
#report = sv.analyze([df, " Exited"])
#report.show_html('common_analysis.html')

# %%
#import pandas_profiling
#pandas_profiling.ProfileReport(df)

# %% [markdown]
# ## Исследуем баланс классов

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>совет </b>  Что за борьба с дисбалансом?) Этот шаг должен быть после исследования. У нас в ТЗ четко указано:
#
# - Сначала исследуйте баланс классов, обучите модель без учёта дисбаланса. Кратко опишите выводы.
# - Затем (борьба с дисбалансом) улучшите качество модели, учитывая дисбаланс классов. Обучите разные модели и найдите лучшую. Кратко опишите выводы.
# - Проведите финальное тестирование (для наилучшей модели с наилучшем методом для борьбы с дисбалансом.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> Заголовок поменял.
# </div>

# %%
#Построим гистограмму сколько ушло/сколько осталось клиентов
df['Exited'].value_counts().plot(kind='bar',grid=True,figsize=(10,6),title='Соотношение тех, сколько ушло/сколько осталось клиентов')
# Out:
# <AxesSubplot:title={'center':'Соотношение тех, сколько ушло/сколько осталось клиентов'}>

# %% [markdown]
# ### Промежуточный итог:
# как видно на графике соотношение 1 к 4 --> присутствует дизбаланс данных.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b>  Дисбаланс обнаружен
# </div>

# %%
#соотносим возраст и ооток клиентов
df.groupby('Age')['Exited'].sum(
                            ).plot(
                            kind='bar',figsize=(15,6),
                            title='Гистограммма возраста и оттока')
plt.show()

# %% [markdown]
# ### Промежуточный итог:
# на графике выделяются пиковые значения
# 39, 43, 45, 46 лет --> в этом возрасте (в разрезе данного df) клиенты чаще всего уходят из банка.

# %%
#соотносим продолжительность обслуживания и ооток клиентов
df.groupby('Tenure')['Exited'].sum(
                            ).plot(
                            kind='bar',figsize=(15,6),
                            title='Гистограммма лет обслуживания и оттока')
plt.show()

# %%
df.groupby('Tenure')['Exited'].sum()
# Out:
# Tenure
# 0     273
# 1     213
# 2     185
# 3     198
# 4     184
# 5     187
# 6     177
# 7     160
# 8     174
# 9     194
# 10     92
# Name: Exited, dtype: int64

# %% [markdown]
# ### Промежуточный итог:
# на графике:
# высокий риск ухода клиента из банка в перывый год обслуживания (до года и год)
# так же выделяется 3 и 9 год.
#
# обязательно делаем поправку на то, что это справедливо для текущего df.

# %%
# Расчитываем матрицу корреляции
df.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783  0.000596
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.015747
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.003087
# Age               0.000783    0.009497    -0.003965  1.000000 -0.007368
# Tenure            0.000596   -0.015747     0.003087 -0.007368  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.005821
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.010106
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.021387
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.025856
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.011225
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.013319
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# строим матрицу рассеяния между признаками
#pd.plotting.scatter_matrix(df, figsize=(15, 20))
#plt.show()
#замена матрицы: 
import seaborn as sns
print('Графики зависимости целевой метки от параметров в данных')
table_graph = df.drop(['RowNumber','CustomerId','HasCrCard','IsActiveMember','NumOfProducts'], axis=1)
sns.pairplot(table_graph, hue='Exited', height=2.5, diag_kind='hist')
plt.show()
# Out:
# Графики зависимости целевой метки от параметров в данных

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет:</b> Корреляцию пирсона/спирмена только для количественных данных. Советую обратить на инструмент <a href="https://phik.readthedocs.io/en/latest/" >phik</a>, который помогает устанавливать связи (не только линейные) между факторами (и не только между количественными)

# %% [markdown]
# #
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> Спасибо за ссылку. почитал дополнительно https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7  так на локальной тетрадке, к сожалению пока ничего не получилось <a href ='https://disk.yandex.ru/i/73GA4XKXJP1HVw'>https://disk.yandex.ru/i/73GA4XKXJP1HVw </a>. думаю, со временем получится разобраться)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> заменил матрицу, на более наглядную.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[2]:</b>  В pandas_profling-е это есть внутри

# %% [markdown]
# ### Промежуточный итог:
# Для понимания взаимосвязи между между признаками составили матрицу корреляции.

# %%
#Удалим столбцы-идентификаторы, не представляющие ценностия для алгоритма и столбцы, которые не участвуют в дальнейшем анализе
for_drop = ['RowNumber','CustomerId', 'Surname']
df = df.drop(for_drop, axis=1)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# вызываем метод get_dummies для избавления от категориальных признаков
df_ohe=pd.get_dummies(df,drop_first=True)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка[2]:</b> Перед кодированием лучше удалить неинформативные признаки, например CustomerId и	Surname

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <br><b>Комментарий студента:</b> Удалил
# <br><b>Вопрос:</b>    CustomerId - разве не должно оставаться? в том плане, что бы после индефицировать клиента или это сейчас делается в разрезе того, что текущему анализу, нам точно не потребуются эти данные. Тогда с таким же посылом вероятно можно убирать Geography, Gender, Age?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ответ[3]:</b> Мы должны рассматривать неинформативность только в разрезе влиянию на целевую. Вряд ли Фамилия или Id поможет нашим моделям предсказывать уйдет ли клиент из банка, а вот местоположение или пол с возрастом, может давать какую-то статистическую информанцию незначительую

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v3:</b> Спасибо за ответ.
# </div>

# %%
#целевой признак
target = df_ohe['Exited']

#признаки
features = df_ohe.drop('Exited', axis=1)

#разбиваем данные на выборки:
####features_train, features_valid, target_train, target_valid = train_test_split(
####    features, target, test_size=0.25, random_state=12345)

#features_temp, test_features, target_temp, test_target = train_test_split(
#    features, target, test_size=0.2, random_state=12345)

#features_train, features_valid, target_train, target_valid = train_test_split(
#    features_temp, target_temp, test_size=0.25, random_state=12345)

#model = LogisticRegression(random_state=12345, solver='liblinear', class_weight='balanced')
#model.fit(features_train, target_train)
#predicted_valid = model.predict(features_valid)
#print("F1:", f1_score(target_valid, predicted_valid))


#print('Признаки обучающей выборки:',features_temp.shape,  
#      '\nЦелевой признак обучающей выборки:', target_temp.shape, 
#      '\nВалидационная и тестовая вместе', test_features.shape, test_target.shape)


####print()
####print('Признаки обучающей выборки:',features_train.shape,  
####      '\nЦелевой признак обучающей выборки:', target_train.shape, 
####      '\nВалидационная и тестовая вместе', features_valid.shape, target_valid.shape)

# %% [markdown]
# <b> Разделение выборки произведем в 2 этапа:</b>
# 1. Выделим валидационную 60%
# 2. Разделим оставшиеся 40% на 2 равные части (валидационная и тестовая)

# %%
#1. Выделим валидационную 60%
features_train, features_validtest, target_train, target_validtest = train_test_split(features,
                                                    target,
                                                    train_size=0.6,
                                                    random_state=12345, 
                                                    stratify=target)

print('Признаки обучающей выборки:',features_train.shape,  
      '\nЦелевой признак обучающей выборки:', target_train.shape, 
      '\nВалидационная и тестовая вместе', features_validtest.shape, target_validtest.shape)
# Out:
# Признаки обучающей выборки: (6000, 11)
# Целевой признак обучающей выборки: (6000,)
# Валидационная и тестовая вместе (4000, 11) (4000,)

# %%
#2. Разделим оставшиеся 40% на 2 равные части (валидационная и тестовая)
features_valid, features_test, target_valid, target_test = train_test_split(features_validtest,
                                                    target_validtest,
                                                    train_size=0.5,
                                                    random_state=12345, 
                                                    stratify=target_validtest)

print('Признаки обучающей выборки:',features_test.shape,  
      '\nЦелевой признак обучающей выборки:', target_test.shape, 
      '\nВалидационная и тестовая вместе', features_valid.shape, target_valid.shape)
# Out:
# Признаки обучающей выборки: (2000, 11)
# Целевой признак обучающей выборки: (2000,)
# Валидационная и тестовая вместе (2000, 11) (2000,)

# %% [markdown]
# <br><b>Полученые выбрки:</b>
# <br>Обучающая
# <br>features_train
# <br>target_train
#
# <br><b>Валидационная</b>
# <br>features_valid
# <br>target_valid
#
# <br><b>Тестовая</b>
# <br>features_test
# <br>target_test

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b>  Нам нужно 3 выборки тренировочная, валидационная  и  тестовая
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> Правильно?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[2]:</b>  да)

# %%
#Для масштабирования зафиксируем численные признаки
numeric = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

#Создадим объект этой структуры и настроим его на обучающих данных:
scaler = StandardScaler()
scaler.fit(features_train[numeric])

#Масштабируем численные признаки обучающей выборки 
features_train[numeric] = scaler.transform(features_train[numeric])
#Масштабируем численные признаки валидационной выборки 
features_valid[numeric] = scaler.transform(features_valid[numeric])
#Масштабируем численные признаки тестовой выборки
features_test[numeric] = scaler.transform(features_test[numeric])

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Отлично, что scaler обучен только на трейне
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> изменение по коду: добавлен scaler для тестовой выборке, добавлены комментарии
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[2]:</b>  А зачем старый код коментировать? Если из изменений ты только строку добавил

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v2:</b> мало ли) убрал.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[3]:</b> Ок)

# %% [markdown]
# ###  Строим модель без учёта баланса:

# %% [markdown]
# #### Дерево решений

# %%
#ищем лучший гиперпараметр max_depth:
for depth in range(1,10,1):
    model_tree=DecisionTreeClassifier(max_depth=depth,random_state=1234).fit(features_train,target_train)
    prediction=model_tree.predict(features_valid)
    print('max_depth:',depth,'F1:',f1_score(target_valid,prediction))
# Out:
# max_depth: 1 F1: 0.0
# max_depth: 2 F1: 0.5203488372093023
# max_depth: 3 F1: 0.5375722543352601
# max_depth: 4 F1: 0.5206349206349208
# max_depth: 5 F1: 0.5454545454545455
# max_depth: 6 F1: 0.5787878787878787
# max_depth: 7 F1: 0.5985611510791367
# max_depth: 8 F1: 0.5683563748079877
# max_depth: 9 F1: 0.564327485380117

# %% [markdown]
# #### Промежуточный итог:
# Лучший гиперпараметр: max_depth: 6 F1: 0.5762195121951219

# %% [markdown]
# #### Случайный лес

# %%
for max_depth in range(1,25,1):
    model_forest=RandomForestClassifier(max_depth=max_depth,n_estimators=50,random_state=1234).fit(features_train,target_train)
    prediction=model_forest.predict(features_valid)
    print('max_depth:',max_depth,'F1:',f1_score(target_valid,prediction))
# Out:
# max_depth: 1 F1: 0.0
# max_depth: 2 F1: 0.2017543859649123
# max_depth: 3 F1: 0.2547770700636943
# max_depth: 4 F1: 0.40151515151515155
# max_depth: 5 F1: 0.5284280936454849
# max_depth: 6 F1: 0.5591054313099041
# max_depth: 7 F1: 0.5632
# max_depth: 8 F1: 0.5709828393135725
# max_depth: 9 F1: 0.5736196319018405
# max_depth: 10 F1: 0.5923664122137404
# max_depth: 11 F1: 0.5920245398773006
# max_depth: 12 F1: 0.5828220858895705
# max_depth: 13 F1: 0.5909090909090909
# max_depth: 14 F1: 0.5951661631419939
# max_depth: 15 F1: 0.5976331360946745
# max_depth: 16 F1: 0.6092124814264487
# max_depth: 17 F1: 0.5937031484257871
# max_depth: 18 F1: 0.5984962406015037
# max_depth: 19 F1: 0.5979073243647235
# max_depth: 20 F1: 0.6086956521739131
# max_depth: 21 F1: 0.6032689450222882
# max_depth: 22 F1: 0.6053412462908012
# max_depth: 23 F1: 0.6
# max_depth: 24 F1: 0.6008968609865472

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет:</b> Что за повтороное разбиение? От таких кусков лучше избавляться, если они не несут информации для ноутбука
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> Промежуточный код убран.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[3]:</b> Есть)

# %% [markdown]
# #### Промежуточный итог:
# Лучший гиперпараметр: max_depth: 23 F1: 0.05250596658711218

# %%
# Циклом подбираем гиперпораметр n_estimators (количество деревьев)
for estim in range(1,50,2):
    model_forest=RandomForestClassifier(max_depth=25,n_estimators=estim,random_state=1234).fit(features_train,target_train)
    prediction=model_forest.predict(features_valid)
    print('estim',estim,'F1:',f1_score(target_valid,prediction))
# Out:
# estim 1 F1: 0.4864197530864197
# estim 3 F1: 0.5652759084791386
# estim 5 F1: 0.5822784810126582
# estim 7 F1: 0.5826086956521739
# estim 9 F1: 0.5915080527086384
# estim 11 F1: 0.581021897810219
# estim 13 F1: 0.5899705014749261
# estim 15 F1: 0.5932452276064611
# estim 17 F1: 0.5911764705882353
# estim 19 F1: 0.5976331360946745
# estim 21 F1: 0.6085672082717873
# estim 23 F1: 0.6035502958579881
# estim 25 F1: 0.6032689450222882
# estim 27 F1: 0.6053412462908012
# estim 29 F1: 0.6044444444444443
# estim 31 F1: 0.6099706744868035
# estim 33 F1: 0.6120058565153733
# estim 35 F1: 0.6014814814814815
# estim 37 F1: 0.6017699115044248
# estim 39 F1: 0.6062407132243686
# estim 41 F1: 0.6011904761904762
# estim 43 F1: 0.6011904761904762
# estim 45 F1: 0.6008968609865472
# estim 47 F1: 0.6101190476190477
# estim 49 F1: 0.6062407132243686

# %% [markdown]
# #### Промежуточный итог:
# Вывод: лучшее значение max_depth=25 и n_estimators=50 при котором F1=0.052.

# %% [markdown]
# ### Обучение с помощью модели Логистической регрессии

# %%
model = LogisticRegression(random_state=12345, solver='liblinear', class_weight='balanced')
model.fit(features_train, target_train)
prediction = model.predict(features_valid)
print("F1:", f1_score(target_valid, prediction))

#просчёт ROC-AUC для логистической регрессии
auc_roc = roc_auc_score(target_valid, prediction)
print("ROC-AUC:",auc_roc)
# Out:
# F1: 0.5302897278314311
# ROC-AUC: 0.7353618583111637

# %% [markdown]
# #### Промежуточный итог:
# Вывод:
# <br>F1: 0.337
# <br>ROC-AUC: 0.553

# %% [markdown]
# #### Общий вывод:
# Данные с дисбалансом (но, с переведенные категориальные и стандартизированные данные) тремя моделями можно сделать вывод, что саммая лучшая модель оказалась Случайный лес.
# <br>Лучшем значении max_depth: 6 F1: 0.576 на тестовой(валидной) выборке.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Шаг проделан неплохо (если его почтистить от ненужных ячеек).
# </div>
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Но нужно еще посчитать ROC-AUC

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> Промежуточный код убрал. вывод поправил. ROC-AUC добаавил.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка[2]:</b>  ROC-AUC Нужно считать от вероятностей 1-го класса: `predict_proba()[:,1]`, а не от самих предсказаний

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v2:</b> Так? код ниже:
# </div>

# %%
#ROC-AUC для леса
probabilities_valid = model.predict_proba(features_valid)
probabilities_one_valid = probabilities_valid[:, 1]
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid)
auc_roc = roc_auc_score(target_valid,probabilities_one_valid)
print('ROC-AUC: {:.2f}'.format(auc_roc))
# Out:
# ROC-AUC: 0.79

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка[2]:</b>  Почему здесь глава называется тестирование? Оно должно быть после борьбы с дисбалансом

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v2:</b> Заголовок убрал
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[3]:</b> Да)

# %% [markdown]
# ### Борьба с дисбалансом

# %% [markdown]
# #### Upsampling
# Воспользуемся функцией Upsampling и увеличим количество клиентов оттока(target==1)

# %%
## Функция Upsampling
def upsampling (features,target,repeat):
    #Разделяем выборку по значениям целевой функции
    target_one=target[target==1]
    target_null=target[target==0]
    features_one=features[target==1]
    features_null=features[target==0]
    
    #Увеличиваем и соединяем обратно
    upsampling_features=pd.concat([features_null]+[features_one]*repeat)
    upsampling_target=pd.concat([target_null]+[target_one]*repeat)
    
    # Перемешиваем
    upsampling_features,upsampling_target=shuffle(upsampling_features,upsampling_target,random_state=1234)
    
    return upsampling_features,upsampling_target

# %%
features_balance_up,target_balance_up=upsampling(features_train,target_train,4)

# %%
print(features_balance_up.shape)
print(target_balance_up.shape)
# Out:
# (9666, 11)
# (9666,)

# %% [markdown]
# #### Downsampling
# Воспользуемся функцией Downsampling и увеличим количество клиентов оттока(target==1)

# %%
def downsampling(features,target,fraction):
    features_null=features[target==0]
    features_one=features[target==1]
    target_null=target[target==0]
    target_one=target[target==1]
    
    downsampling_features=pd.concat([features_null.sample(frac=fraction,random_state=1234)]+[features_one])
    downsampling_target=pd.concat([target_null.sample(frac=fraction,random_state=1234)]+[target_one])
    
    downsampling_features,downsampling_target=shuffle(downsampling_features,downsampling_target,random_state=1234)
    return downsampling_features,downsampling_target

# %%
features_balance_down,target_balance_down=downsampling(features,target,0.25)
print(features_balance_down.shape)
print(target_balance_down.shape)
# Out:
# (4028, 11)
# (4028,)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Ошибка:</b> <br> 1) Если наверху в upsample мы увеличиваем 1-ый класс в 4 раза, чтобы исправить дисбаланс, то в downsample во сколько мы должны сократить 0-ой класс для исправления дисбалнса? <br> 2) Ты сначала применил upsample и записал результат в переменные: `features_balance_up,target_balance_up=upsampling(features_train,target_train,4)`,  <br>А потом просто стер применив downsample и перезаписав в них результат:
#     `features_balance_up,target_balance_up=downsampling(features,target,0.4)`. Это два разных метода, должны быть в разных переменных и должны быть оба исследованы <br>
# 3) Ты должен применять к downsample только тренировочные данные, а не все. `features_balance_up,target_balance_up=downsampling(features,target,0.4)`

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> Поменял переменную features_balance_down,target_balance_down.
#  добавил .shape.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка[2]:</b> В downsample мы должно использовать 0.25, так как у нас соотношение классов 1 к 4. Вызова target.value_counts() покажет исправили мы дисбаланс или нет

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v2:</b> Изменения кода выше в downsampling
#
# <br>1.  заменил downsampling с frac=0.4 на
# frac=fraction
# <br>2. downsampling(features,target,0.4) -->  downsampling(features,target,0.25)
# <br>3. По вашему: target.value_counts()  - не совсем понял. т.к. в тренажере проверялось через .shape и конкретно в target - так и будут "исходные значения" т.е. проверка features_balance_down и target_balance_down должна быть.
#    <br>если не прав, то покажите код пожалуйста.
#     <br>Код из тренажера, на который оринтировался: <a href="https://disk.yandex.ru/i/QyQg79HPtmQIWA">https://disk.yandex.ru/i/QyQg79HPtmQIWA</a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[3]:</b> через shape проверяется размерность данных, но не соотношение классов, снизу  в закомментированной ячейке ты правильно вывел соотношение

# %%
target.value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Все что ты делаешь ниже должно быть в этом разделе, тестирование это своей другой логический этап

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> Заголовок переместил
# </div>

# %% [markdown]
# ### После балансирования данных. Обучение с помощью модели Дерево решения

# %%
"""старый
# %%time
# Циклом ищем лучший гиперпораметр max_depth

for depth in range(1,20,1):
    model_tree=DecisionTreeClassifier(class_weight='balanced',max_depth=depth,random_state=1234).fit(features_balance_up,target_balance_up)
  
    prediction=model_tree.predict(features_valid)
    print('max_depth:',depth,'F1:',f1_score(target_valid,prediction))
    
#print('F1:', np.max(f1_score(target_valid,prediction)))"""
# Out:
# "старый\n%%time\n# Циклом ищем лучший гиперпораметр max_depth\n\nfor depth in range(1,20,1):\n    model_tree=DecisionTreeClassifier(class_weight='balanced',max_depth=depth,random_state=1234).fit(features_balance_up,target_balance_up)\n  \n    prediction=model_tree.predict(features_valid)\n    print('max_depth:',depth,'F1:',f1_score(target_valid,prediction))\n    \n#print('F1:', np.max(f1_score(target_valid,prediction)))"

# %%
# %%time
# Циклом ищем лучший гиперпораметр max_depth

for depth in range(1,20,1):
    for estim in range(25,200,25):
        model_tree=DecisionTreeClassifier(class_weight='balanced',max_depth=depth,random_state=1234).fit(features_balance_up,target_balance_up)
  
    prediction=model_tree.predict(features_valid)
    print('max_depth:',depth,'F1:',f1_score(target_valid,prediction))
# Out:
# max_depth: 1 F1: 0.4846526655896607
# max_depth: 2 F1: 0.49801113762927607
# max_depth: 3 F1: 0.5207100591715977
# max_depth: 4 F1: 0.560931899641577
# max_depth: 5 F1: 0.5546492659053834
# max_depth: 6 F1: 0.575925925925926
# max_depth: 7 F1: 0.5750452079566003
# max_depth: 8 F1: 0.5502262443438914
# max_depth: 9 F1: 0.5419479267116682
# max_depth: 10 F1: 0.527363184079602
# max_depth: 11 F1: 0.5247933884297521
# max_depth: 12 F1: 0.5168067226890756
# max_depth: 13 F1: 0.5197368421052632
# max_depth: 14 F1: 0.5252525252525252
# max_depth: 15 F1: 0.5156794425087108
# max_depth: 16 F1: 0.5162037037037037
# max_depth: 17 F1: 0.5172004744958482
# max_depth: 18 F1: 0.507177033492823
# max_depth: 19 F1: 0.5
# CPU times: user 3.78 s, sys: 3.28 ms, total: 3.78 s
# Wall time: 3.82 s

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Вопрос студента:</b> А какой будет код, что бы выбиралось максимальное значение F1?.
# нашел <a href="https://stackoverflow.com/questions/57060907/compute-maximum-f1-score-using-precision-recall-curve">stackoverflow</a> но знаний не хватает, что бы его применить к текущему коду. Покажите пожалуйста.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Ответ[2]:</b>  С деревом  нормальный перебор гиперпарметров. А для случайного леса я бы рекокмендовал рассмотреть такой диапазон значений параметров
#
#     for max_depth in range(1,20,1):
#         for estim in range(25,200,25):

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Ответ v2:</b> строчку добавил, но как сделать так, что бы выдало только максимальное значение f1 - не понял. получается вывести только максимальный - max_depth.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет[3]:</b> Просто запоминай наилучший f1 в переменную)
#
#     best_f1 = 0
#     best_depth = None
#     best_estim = None
#         for depth in range(1,20,1):
#             for estim in range(25,200,25):
#                 model_tree=DecisionTreeClassifier(class_weight='balanced',max_depth=depth,random_state=1234)
#                 model.fit(features_balance_up,target_balance_up)
#             prediction=model_tree.predict(features_valid)
#             f1 = f1_score(target_valid,prediction)
#             print('max_depth:',depth,'F1:', f1)
#             if f1 > best_f1:
#                 best_f1 = f1
#                 best_depth = depth
#                 best_estim = estim
#     print('f1: ', best_f1, 'width depth: ', best_depth, "with estim: ", best_estim)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v3:</b> спасибо, отличное решение.
# </div>

# %%
# %%time

#from sklearn.tree import DecisionTreeClassifier
best_f1 = 0
best_depth = None
best_estim = None
for depth in range(1,20,1):
    for estim in range(25,200,25):
        model_tree=DecisionTreeClassifier(class_weight='balanced',max_depth=depth,random_state=1234).fit(features_balance_up,target_balance_up)
        prediction=model_tree.predict(features_valid)
    f1 = f1_score(target_valid,prediction)
    print('max_depth:',depth,'F1:', f1)
    if f1 > best_f1:
        best_f1 = f1
        best_depth = depth
        best_estim = estim
print()
print()
print('f1: ', best_f1, 'width depth: ', best_depth, "with estim: ", best_estim)
# Out:
# max_depth: 1 F1: 0.4846526655896607
# max_depth: 2 F1: 0.49801113762927607
# max_depth: 3 F1: 0.5207100591715977
# max_depth: 4 F1: 0.560931899641577
# max_depth: 5 F1: 0.5546492659053834
# max_depth: 6 F1: 0.575925925925926
# max_depth: 7 F1: 0.5750452079566003
# max_depth: 8 F1: 0.5502262443438914
# max_depth: 9 F1: 0.5419479267116682
# max_depth: 10 F1: 0.527363184079602
# max_depth: 11 F1: 0.5247933884297521
# max_depth: 12 F1: 0.5168067226890756
# max_depth: 13 F1: 0.5197368421052632
# max_depth: 14 F1: 0.5252525252525252
# max_depth: 15 F1: 0.5156794425087108
# max_depth: 16 F1: 0.5162037037037037
# max_depth: 17 F1: 0.5172004744958482
# max_depth: 18 F1: 0.507177033492823
# max_depth: 19 F1: 0.5
#
#
# f1:  0.575925925925926 width depth:  6 with estim:  175
# CPU times: user 3.93 s, sys: 23.3 ms, total: 3.96 s
# Wall time: 4 s

# %% [markdown]
# ### После балансирования данных. Обучение с помощью модели Случайный лес

# %%
# %%time
# Циклом ищем лучший гиперпораметр max_depth

for max_depth in range(1,20,1):
    model_forest=RandomForestClassifier(class_weight='balanced',max_depth=max_depth,n_estimators=50,random_state=1234).fit(features_balance_up,target_balance_up)
    prediction=model_forest.predict(features_valid)
    print('max_depth:',max_depth,'F1:',f1_score(target_valid,prediction))
# Out:
# max_depth: 1 F1: 0.5841495992876226
# max_depth: 2 F1: 0.591123701605288
# max_depth: 3 F1: 0.6005719733079122
# max_depth: 4 F1: 0.6042632066728453
# max_depth: 5 F1: 0.6147934678194044
# max_depth: 6 F1: 0.6168768186226964
# max_depth: 7 F1: 0.6382978723404256
# max_depth: 8 F1: 0.6422594142259413
# max_depth: 9 F1: 0.6485310119695321
# max_depth: 10 F1: 0.6482300884955752
# max_depth: 11 F1: 0.6398158803222094
# max_depth: 12 F1: 0.6356228172293364
# max_depth: 13 F1: 0.6304347826086957
# max_depth: 14 F1: 0.6096654275092936
# max_depth: 15 F1: 0.631979695431472
# max_depth: 16 F1: 0.6327827191867853
# max_depth: 17 F1: 0.6226912928759895
# max_depth: 18 F1: 0.6202365308804205
# max_depth: 19 F1: 0.6194926568758344
# CPU times: user 7.27 s, sys: 67.4 ms, total: 7.34 s
# Wall time: 7.38 s

# %%
# %%time
# Циклом подбираем гиперпораметр n_estimators (количество деревьев)
for estim in range(1,51,1):
    model_forest=RandomForestClassifier(class_weight='balanced',max_depth=9,n_estimators=estim,random_state=1234).fit(features_balance_up,target_balance_up)
    prediction=model_forest.predict(features_valid)
    print('estim',estim,'F1:',f1_score(target_valid,prediction))
# Out:
# estim 1 F1: 0.5696846388606307
# estim 2 F1: 0.5634365634365635
# estim 3 F1: 0.5885885885885885
# estim 4 F1: 0.5932028836251287
# estim 5 F1: 0.6010362694300518
# estim 6 F1: 0.6126315789473684
# estim 7 F1: 0.6142401700318809
# estim 8 F1: 0.616862326574173
# estim 9 F1: 0.6187363834422659
# estim 10 F1: 0.6097297297297297
# estim 11 F1: 0.6192560175054705
# estim 12 F1: 0.6215921483097055
# estim 13 F1: 0.618063112078346
# estim 14 F1: 0.6267682263329706
# estim 15 F1: 0.6222707423580786
# estim 16 F1: 0.6212121212121212
# estim 17 F1: 0.6198704103671706
# estim 18 F1: 0.6177105831533477
# estim 19 F1: 0.6213592233009709
# estim 20 F1: 0.6256742179072277
# estim 21 F1: 0.6336206896551725
# estim 22 F1: 0.6327193932827736
# estim 23 F1: 0.6328293736501079
# estim 24 F1: 0.6370530877573131
# estim 25 F1: 0.6304347826086956
# estim 26 F1: 0.6363636363636364
# estim 27 F1: 0.6406080347448426
# estim 28 F1: 0.6363636363636364
# estim 29 F1: 0.6441784548422197
# ...

# %%
 model_forest=RandomForestClassifier(class_weight='balanced',max_depth=9,n_estimators=50,random_state=1234).fit(features_balance_up,target_balance_up)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Вопрос[2]:</b>  Почему max_depth=11 используется? а estimators=50? Почему ты их такими выбрал? Ведь в твоем выводе результатов ты получаешь максимальные значения метрик с другими параметрами

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v2:</b> по пункту 3.9. у меня получились максимальные значения: max_depth=9 (поменял), estimators=50 (осталось). <a href = "https://docs.google.com/spreadsheets/d/17DFVHavP2lj5RTiFtXufbmWHOl8FH4eIV_D6DHiILFY/edit?usp=sharing">link</a>
#
# <br>поясните пожалуйста, если я где то сейчас ошибаюсь.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[3]:</b> Да, все верно, в прошлый раз было не так.

# %% [markdown]
# ### После балансирования данных. Обучение с помощью модели Логистической регрессии

# %%
# %%time
model_logistic=LogisticRegression(
    random_state=12345, solver='liblinear').fit(
    features_balance_up,target_balance_up)
prediction=model_logistic.predict(features_valid)
print('F1:',f1_score(target_valid,prediction))

auc_roc = roc_auc_score(target_valid, prediction)
print("ROC-AUC:",auc_roc)
# Out:
# F1: 0.5246753246753246
# ROC-AUC: 0.7318762932308602
# CPU times: user 29.7 ms, sys: 23.8 ms, total: 53.5 ms
# Wall time: 24.8 ms

# %% [markdown]
# # Вывод:
# Изменения незначительные:
# 1. Мера F1: 0.524 (было: F1: 0.337)
# 2. ROC-AUC: 0.732 (было: 0.553)

# %% [markdown]
# # Исследование метрика AUC-ROC

# %%
#ROC для логистической регрессии
probabilities_tree=model_tree.predict_proba(features_valid)
probabilities_one_valid_tree=probabilities_tree[:,1]
fpr_tree,tpr_tree,thresholds=roc_curve(target_valid,probabilities_one_valid_tree)

auc_roc_tree=roc_auc_score(target_valid,probabilities_one_valid_tree)
print("AUC-ROC деревья решений.:", auc_roc_tree)
# Out:
# AUC-ROC деревья решений.: 0.6895607017932802

# %%
"""
#Для логистической регрессии расчитаем метрику AUC-ROC
model_LgR = LogisticRegression(solver = 'liblinear', class_weight='balanced')
model_LgR.fit(features_train, target_train)
LgR_probabilities_one_valid_class_weight = model_LgR.predict_proba(features_valid)[:, 1]
print("Score", model_LgR.score(features_valid, target_valid))
print("AUC-ROC", roc_auc_score(target_valid, LgR_probabilities_one_valid_class_weight))
fpr, tpr, thresholds = roc_curve(target_valid, LgR_probabilities_one_valid_class_weight)
"""
# Out:
# '\n#Для логистической регрессии расчитаем метрику AUC-ROC\nmodel_LgR = LogisticRegression(solver = \'liblinear\', class_weight=\'balanced\')\nmodel_LgR.fit(features_train, target_train)\nLgR_probabilities_one_valid_class_weight = model_LgR.predict_proba(features_valid)[:, 1]\nprint("Score", model_LgR.score(features_valid, target_valid))\nprint("AUC-ROC", roc_auc_score(target_valid, LgR_probabilities_one_valid_class_weight))\nfpr, tpr, thresholds = roc_curve(target_valid, LgR_probabilities_one_valid_class_weight)\n'

# %%
#ROC для леса
probabilities_forest=model_forest.predict_proba(features_valid)
probabilities_one_valid_forest=probabilities_forest[:,1]
fpr_forest,tpr_forest,thresholds=roc_curve(target_valid,probabilities_one_valid_forest)
auc_roc_forest=roc_auc_score(target_valid,probabilities_one_valid_forest)
print("AUC-ROC, леса:", auc_roc_forest)
# Out:
# AUC-ROC, леса: 0.8729477657897331

# %%
#ROC лог регрессии
probabilities_reg=model_logistic.predict_proba(features_valid)
probabilities_one_valid_reg=probabilities_reg[:,1]
fpr_log,tpr_log,thresholds=roc_curve(target_valid,probabilities_one_valid_reg)
auc_roc_reg=roc_auc_score(target_valid,probabilities_one_valid_reg)
print("AUC-ROC,лог регрессии:", auc_roc_reg)
# Out:
# AUC-ROC,лог регрессии: 0.7938220514336388

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ответ[2]:</b>  В комментарии ты пишешь ROC дерево, а в print-е пишешь регрессия.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v2:</b> Поправил
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[3]:</b> Есть

# %%
plt.figure()

plt.figure(figsize=(10,7))
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])


#plt.plot(fpr_log,tpr_log) 
plt.plot(fpr,tpr)#логистической регрессии
plt.plot(fpr_tree,tpr_tree)#дерево решений
plt.plot(fpr_forest,tpr_forest)#лес


plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend(('Случайная модель', 'Логистическая регрессия', 'Дерево решения',  'Случайный лес'),
           loc= 'upper left') 
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ответ[2]:</b> Ты уверен, что у тебя в правильном порядке стоит названия кривых?

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v2:</b> Исправил.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[3]:</b> Отлично

# %%
#попробуем обучать логистическую регресию сбалансировав классы
model_LgR = LogisticRegression(solver = 'liblinear', class_weight='balanced')
model_LgR.fit(features_train, target_train)
LgR_probabilities_one_valid_class_weight = model_LgR.predict_proba(features_valid)[:, 1]
print("Score", model_LgR.score(features_valid, target_valid))
print("AUC-ROC", roc_auc_score(target_valid, LgR_probabilities_one_valid_class_weight))

fpr, tpr, thresholds = roc_curve(target_valid, LgR_probabilities_one_valid_class_weight) 
plt.figure()
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.show()
# Out:
# Score 0.7325
# AUC-ROC 0.7937758646172037

# %% [markdown]
# ### Итог:
# Значение площади под кривой. На сколько наша модель отличается от случайной
#
# Лучшее значение метрики auc roc= 0.834 у модели Случайный лес

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Нужно обновить вычисления исследовав все методы для борьбы с дисбалансом отдельно друг от друга: downsample/upsample/class_weight:'balanced'

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> Изменения по коду повлияли на графики. итог переписал.
#     <br>если что-то ещё нужно было сделать? подскажи, что?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Ответ[2]:</b>  `class_weight:'balanced'` - это тоже метод для борьбы с дисбалансом, его везде желательно попробовать с стандартными данными, а не `upsampled/downsampled`. Ты так сделал в LogisticRegression, а вот в других моделих использовах этот метод с upsampled данными

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v2:</b> Пожалуйста: Прошу больше подсказки/конкретнее что и как делать?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Ответ[3]:</b>У тебя при работе с моделями выполняется такая строка `RandomForestClassifier(class_weight='balanced',max_depth=9,n_estimators=estim,random_state=1234).fit(features_balance_up,target_balance_up)`
#
# Как можно заметить
#
# 1) у тебя используется параметр `class_weight='balanced'`
#
# 2) и обучаются они на umsampled данных: `.fit(features_balance_up,target_balance_up)`
#
#
# Оба эти момента являются методами для борьбы с дисбаансом, их можно использовать вместе, но в данной работе лучше их попробовать отдельно друг от , не совмещать.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v3:</b> Так? код ниже:
# </div>

# %%
# %%time
model_forest_1 = RandomForestClassifier(class_weight='balanced',max_depth=9,n_estimators=50,random_state=1234)
model_forest_1.fit(features_balance_up,target_balance_up)
    
#prediction=model_forest.predict(features_valid)
#print('estim',estim,'F1:',f1_score(target_valid,prediction))

predicted_forest_valid = model.predict(features_valid)
print('valid f1:', f1_score(target_valid, predicted_forest_valid))

predicted_forest_test = model.predict(features_test)
print('test f1:', f1_score(target_test, predicted_forest_valid))
# Out:
# valid f1: 0.5302897278314311
# test f1: 0.265377855887522
# CPU times: user 391 ms, sys: 47.4 ms, total: 439 ms
# Wall time: 392 ms

# %% [markdown]
# # Общий вывод:

# %%
rez={'Дерево Решения':np.array(
    [0.576,0.574]),'Случайный лес':np.array(
    [0.576,0.588]),'Логистическая регрессия':np.array(
    [0.337,0.338])}
rez_df=pd.DataFrame(rez,index=['f1 без учета дисбаланса','f1 с учетом дисбаланса'])
rez_df
# Out:
#                          Дерево Решения  Случайный лес  \
# f1 без учета дисбаланса           0.576          0.576
# f1 с учетом дисбаланса            0.574          0.588
#
#                          Логистическая регрессия
# f1 без учета дисбаланса                    0.337
# f1 с учетом дисбаланса                     0.338

# %% [markdown]
# Рассматривая данные с учетом дисбаланса + переведенные категориальные + стандартизированные данные и без учета дисбаланса тремя моделями можно сделать вывод, что самая лучшая модель оказалась Случайный лес (max_depth=9, estimators=50). Хуже всего себя показала модель Логистическая регрессия

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Это не R2 это F-мера. Также наилучшая модель должна пройти тестирование на тестовой выборке

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента:</b> Поменял данные.
#    <br> тестирование на тестовой: правильно ли я понимаю, что нужно для случайного леса повторить все шаги их п. 4 с Тестовая
# <br>features_test
# <br>target_test?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ответ[2]:</b>  Нет, на прошлом шаге мы исследуем дисбаланс и модели, то есть находим наилучшую комбинацию: метод для борьбы с дисбалансом - модель машинного обучения - гиперпараметры. И выбрав эту самую комбинацию, проводим для нее тестирование. То есть просто предсказываем на тестовой выборке и полчему f1 и roc-auc оценки.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v2:</b> т.е в моём случае берем Random Forest Classifier max_depth=9, estimators=50?
#     <br>прошу подсказку или ссылку, что делать.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ответ[3]:</b> Да, абсолютно верно, но тебе осталось проести тестирование. То есть получит f1, roc-auc на тестовых данных (используя наилучшую модель)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v3:</b> Так, код в п. 4.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Ответ[4]:</b> Тестирвоание от слова тест. У тебя есть для этого выборка - нужно ее использовать: `features_test`.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v4:</b> Изменил код в п. 4. на features_test. Так?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Ответ[5]:</b> Да, только ROC_AUC нужно считать от вероятносей 1-го класса так:  `roc_auc_score(target_test, model_forest.predict_proba(features_test)[:,1])`

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <div >
# <b>Комментарий студента v5:</b> Исправил код на ваш. спасибо за подсказку
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[5]:</b> Есть контакт

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# Лучший результат показала модель Random Forest Classifier с глубиной 9 и количеством деревьев 50

# %% [markdown]
# Посчитаем AUC-ROC для нашей модели и посмотрим насколько она лучше случайной модели

# %%
prediction=model_forest.predict(features_test)
print('F1:',f1_score(target_test, prediction))
print('AUC-ROC для тестовой модели:',roc_auc_score(target_test, model_forest.predict_proba(features_test)[:,1]))
# Out:
# F1: 0.6023835319609968
# AUC-ROC для тестовой модели: 0.8557679405137031

# %% [markdown]
# ### итог тестирования:
# F1-мера на тестовой выборке больше 0.59. Что и требовалось по описанию задачи.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[5]:</b> С тестированием все в порядке, получено хорошее качество на тесте

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: задача исследована
#     - [x]  Исследован баланс классов
#     - [x]  Изучены модели без учёта дисбаланса
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 3: учтён дисбаланс
#     - [x]  Применено несколько способов борьбы с дисбалансом
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 4: проведено тестирование
# - [x]  Удалось достичь *F1*-меры не менее 0.59
# - [x]  Исследована метрика *AUC-ROC*
